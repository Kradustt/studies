# %%
import string

print(string.ascii_letters)
print(string.digits)
print(string.punctuation)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def gerar_senha(tamanho):
    if tamanho < 4:
        print("O tamanho tem que ser maior que 4 caracteres")
    

tamanho = int(input("Digite o tamanho da sua senha aqui : "))
print(gerar_senha(tamanho))
# Out:
# None
