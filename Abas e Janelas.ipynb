# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver #- quem da os comandos para abrir o navegador
from selenium.webdriver.chrome.service import Service # <- "S" Maiúsculo aqui!
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By


# 1. Cria o serviço usando a classe correta (Service com S maiúsculo)
servico = Service(ChromeDriverManager().install())

# 2. Configura as opções do Chrome
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Caso queira a tela cheia que vimos antes
# options.add_argument("user-data-dir=C:\User\") # Caso queira abrir já com o seu perfil do nav (chrome://version)

# 3. Abre o navegador passando TANTO o serviço QUANTO as opções
driver = webdriver.Chrome(service=servico, options=options) 

driver.get("https://www.google.com/")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\joaol\.wdm\drivers\chromedriver\win32\99.0.4844.51]

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Pagina Hashtag.html"
driver.get(arquivo)

# %% [markdown]
# #### Botão que abre outra janela

# %%
driver.find_element(By.XPATH, '/html/body/section[2]/div/div[4]/figure/a/img').click()

# %%
# preenchendo o formulario

driver.find_element(By.ID, 'fullname').send_keys("LiraLira")

# %% [markdown]
# ### Outra aba / muda para outra aba

# %%
aba_original = driver.window_handles[0]
nova_aba = driver.window_handles[1]
driver.switch_to.window(nova_aba)
driver.find_element(By.ID, 'fullname').send_keys("LiraNovaAba")

# %%
driver.find_element(By.ID, 'email').send_keys("lira@lira.com")

# %% [markdown]
# ### Identificar qual aba é qual item da lista do window_handles

# %%
# ver os titulos de todas as abas
for aba in driver.window_handles:
    driver.switch_to.window(aba)
    print(driver.title)

# %% [markdown]
# ### Outra janela

# %%
abas = driver.window_handles
print(len(abas))
nova_janela = driver.window_handles[2]
driver.switch_to.window(nova_janela)
# Out:
# 3

# %%
driver.find_element(By.ID, 'fullname').send_keys("LiraJanela")
driver.find_element(By.ID, 'email').send_keys("janela@lira.com")

# %% [markdown]
# ## fechar a aba atualmente selecionada

# %%
driver.close()
# fechar todas as abas (driver inteiro)
driver.quit()
